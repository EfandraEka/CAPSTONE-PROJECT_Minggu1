# %% [markdown]
# <a href="https://colab.research.google.com/github/EfandraEka/CAPSTONE-PROJECT_Minggu1/blob/main/CAPSTONE_PROJECT_BENGKOD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
import streamlit as st
import streamlit.components.v1 as stc
from PIL import Image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 87.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set tema tampilan visual dari seaborn agar lebih menarik
sns.set(style="whitegrid")

# %% [markdown]
# Penjelasan:
#
# pandas digunakan untuk manipulasi data (membaca file, analisis tabular).
#
# numpy digunakan untuk operasi numerik (opsional).
#
# matplotlib.pyplot dan seaborn digunakan untuk membuat visualisasi data.
#
# sns.set() mengatur tampilan plot agar lebih bersih dan estetis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('drive/MyDrive/Colab Notebooks/ObesityDataSet.csv')

# %% [markdown]
# Penjelasan:
# Baris ini membaca file CSV dan menyimpannya ke dalam DataFrame bernama df.

# %%
# Menampilkan 5 baris pertama dari dataset
print(" Contoh Data:")
print(df.head())
# Out:
#  Contoh Data:
#   Age  Gender Height Weight        CALC FAVC FCVC NCP  SCC SMOKE CH2O  \
# 0  21  Female   1.62     64          no   no    2   3   no    no    2
# 1  21  Female   1.52     56   Sometimes   no    3   3  yes   yes    3
# 2  23    Male    1.8     77  Frequently   no    2   3   no    no    2
# 3  27    Male    1.8     87  Frequently   no    3   3   no    no    2
# 4  22    Male   1.78   89.8   Sometimes   no    2   1   no    no    2
#
#   family_history_with_overweight FAF TUE       CAEC                 MTRANS  \
# 0                            yes   0   1  Sometimes  Public_Transportation
# 1                            yes   3   0  Sometimes  Public_Transportation
# 2                            yes   2   1  Sometimes  Public_Transportation
# 3                             no   2   0  Sometimes                Walking
# 4                             no   0   0  Sometimes  Public_Transportation
#
#             NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# ...

# %% [markdown]
# Penjelasan:
# Untuk melihat gambaran isi dataset, kolom, dan contoh nilai dari data.

# %%
# Menampilkan informasi struktur dataset (jumlah baris, kolom, dan tipe data)
print("\n Informasi Dataset:")
print(df.info())
# Out:
#  Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2097 non-null   object
#  1   Gender                          2102 non-null   object
#  2   Height                          2099 non-null   object
#  3   Weight                          2100 non-null   object
#  4   CALC                            2106 non-null   object
#  5   FAVC                            2100 non-null   object
#  6   FCVC                            2103 non-null   object
#  7   NCP                             2099 non-null   object
#  8   SCC                             2101 non-null   object
#  9   SMOKE                           2106 non-null   object
#  10  CH2O                            2105 non-null   object
# ...

# %% [markdown]
# Penjelasan:
# Menampilkan ringkasan struktur dataset seperti jumlah non-null, tipe data, dll.

# %%
# Statistik deskriptif untuk kolom numerik
print("\n Statistik Deskriptif:")
print(df.describe())
# Out:
#  Statistik Deskriptif:
#          Age Gender Height Weight       CALC  FAVC  FCVC   NCP   SCC SMOKE  \
# count   2097   2102   2099   2100       2106  2100  2103  2099  2101  2106
# unique  1394      3   1562   1518          5     3   808   637     3     3
# top       18   Male    1.7     80  Sometimes   yes     3     3    no    no
# freq     124   1056     58     58       1386  1844   647  1183  1997  2054
#
#         CH2O family_history_with_overweight   FAF   TUE       CAEC  \
# count   2105                           2098  2103  2102       2100
# unique  1263                              3  1186  1130          5
# top        2                            yes     0     0  Sometimes
# freq     441                           1705   404   552       1747
#
#                        MTRANS      NObeyesdad
# count                    2105            2111
# unique                      6               7
# top     Public_Transportation  Obesity_Type_I
# ...

# %% [markdown]
# Penjelasan:
# Memberikan ringkasan statistik (mean, std, min, max, Q1, Q3) dari kolom numerik.

# %%
# Mengecek apakah ada data yang kosong (missing values)
print("\n Missing Values:")
print(df.isnull().sum())
# Out:
#  Missing Values:
# Age                               14
# Gender                             9
# Height                            12
# Weight                            11
# CALC                               5
# FAVC                              11
# FCVC                               8
# NCP                               12
# SCC                               10
# SMOKE                              5
# CH2O                               6
# family_history_with_overweight    13
# FAF                                8
# TUE                                9
# CAEC                              11
# MTRANS                             6
# NObeyesdad                         0
# dtype: int64

# %% [markdown]
# Penjelasan:
# Menampilkan jumlah nilai kosong (null) di setiap kolom.

# %%
# Mengecek apakah ada baris yang sama persis (duplikat)
print("\n Duplikat:")
print(f"Jumlah baris duplikat: {df.duplicated().sum()}")
# Out:
#  Duplikat:
# Jumlah baris duplikat: 18

# %% [markdown]
# Penjelasan:
# Menghitung jumlah baris yang duplikat dalam dataset.

# %%
# Melihat jumlah nilai unik di setiap kolom
print("\n Nilai Unik per Kolom:")
print(df.nunique())
# Out:
#  Nilai Unik per Kolom:
# Age                               1394
# Gender                               3
# Height                            1562
# Weight                            1518
# CALC                                 5
# FAVC                                 3
# FCVC                               808
# NCP                                637
# SCC                                  3
# SMOKE                                3
# CH2O                              1263
# family_history_with_overweight       3
# FAF                               1186
# TUE                               1130
# CAEC                                 5
# MTRANS                               6
# NObeyesdad                           7
# dtype: int64

# %% [markdown]
# Penjelasan:
# Menampilkan jumlah nilai berbeda (unik) per kolom. Ini membantu mengenali fitur kategorikal.

# %%
# Visualisasi distribusi kelas target
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='NObeyesdad', order=df['NObeyesdad'].value_counts().index)
plt.xticks(rotation=45)
plt.title("Distribusi Kelas Obesitas (Target: NObeyesdad)")
plt.xlabel("Kategori Obesitas")
plt.ylabel("Jumlah")
plt.tight_layout()
plt.show()

# %% [markdown]
# Penjelasan:
# Menampilkan plot jumlah data untuk setiap kategori kelas obesitas. rotation=45 memiringkan label agar tidak tumpang tindih.

# %%
# Menampilkan proporsi masing-masing kelas target dalam persen
print("\n Distribusi Kelas Target:")
print(df['NObeyesdad'].value_counts(normalize=True) * 100)
# Out:
#  Distribusi Kelas Target:
# NObeyesdad
# Obesity_Type_I         16.627191
# Obesity_Type_III       15.348176
# Obesity_Type_II        14.069162
# Overweight_Level_I     13.737565
# Overweight_Level_II    13.737565
# Normal_Weight          13.595452
# Insufficient_Weight    12.884889
# Name: proportion, dtype: float64

# %% [markdown]
# Penjelasan:
# Menampilkan persentase distribusi setiap kelas obesitas, untuk mengecek apakah data seimbang atau tidak.

# %%
# Daftar kolom numerik
numerical_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %% [markdown]
# Penjelasan:
# Membuat daftar kolom yang berisi nilai numerik.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set latar belakang putih bersih dan palet warna soft
sns.set(style="whitegrid")

# Loop untuk menampilkan boxplot untuk setiap fitur numerik
for col in numerical_cols:
    plt.figure(figsize=(10, 5))

    # Gunakan hue yang sama dengan x untuk menghindari future warning
    sns.boxplot(
        data=df,
        x='NObeyesdad',
        y=col,
        hue='NObeyesdad',         # Tambahkan hue untuk menghindari warning
        dodge=False,              # Supaya satu warna per kategori
        palette='Pastel1',
        legend=False              # Hilangkan legend ganda
    )

    # Tambahkan judul dan label sumbu
    plt.title(f'Distribusi {col} Berdasarkan Kategori Obesitas', fontsize=14, fontweight='bold')
    plt.xlabel('Kategori Obesitas', fontsize=12)
    plt.ylabel(col, fontsize=12)

    # Rotasi label x agar terbaca
    plt.xticks(rotation=45)

    # Hapus garis tepi
    sns.despine()

    # Tata letak agar tidak terpotong
    plt.tight_layout()

    # Tampilkan visualisasi
    plt.show()

# %% [markdown]
# Penjelasan:
# Melakukan visualisasi sebaran nilai fitur numerik terhadap masing-masing kelas obesitas. Membantu melihat perbedaan pola tiap fitur antar kelas.
#
# hue='NObeyesdad' ditambahkan agar sesuai dengan saran dari Seaborn terbaru, dan mencegah warning.
#
# dodge=False memastikan setiap kategori tidak digeser ke samping secara terpisah.
#
# legend=False mencegah munculnya legend ganda karena x dan hue sama.
#
# sns.set(style="whitegrid") membuat tampilan lebih bersih dengan latar putih dan grid halus.

# %%
# Menampilkan outlier tanpa membedakan kelas
num_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
plt.figure(figsize=(15,10))
for i, col in enumerate(num_cols):
    plt.subplot(3, 3, i+1)
    sns.boxplot(x=df[col])
    plt.title(f'Outlier: {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Penjelasan:
# Mendeteksi nilai ekstrim (outlier) di setiap kolom numerik secara umum, tanpa mempertimbangkan kategori obesitas.

# %%
# Menampilkan korelasi antar fitur numerik dalam bentuk heatmap
for col in numerical_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

plt.figure(figsize=(10, 8))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap Korelasi Fitur Numerik")
plt.tight_layout()
plt.show()

# %% [markdown]
# Penjelasan:
# Membuat visualisasi matriks korelasi antar fitur numerik. Nilai mendekati +1 atau -1 menunjukkan hubungan yang kuat antara dua variabel.

# %%
print("\n Kesimpulan Sementara:")
print("- Tidak ditemukan missing values dalam dataset.")
print("- Sebagian kelas target tidak seimbang (akibat SMOTE).")
print("- Beberapa outlier ditemukan pada fitur seperti Weight, FAF, dan TUE.")
print("- Korelasi menunjukkan bahwa Weight dan Height sangat berpengaruh terhadap kelas obesitas.")
# Out:
#  Kesimpulan Sementara:
# - Tidak ditemukan missing values dalam dataset.
# - Sebagian kelas target tidak seimbang (akibat SMOTE).
# - Beberapa outlier ditemukan pada fitur seperti Weight, FAF, dan TUE.
# - Korelasi menunjukkan bahwa Weight dan Height sangat berpengaruh terhadap kelas obesitas.

# %% [markdown]
# Penjelasan:
# Kesimpulan sementara yang ditarik dari hasil EDA sebelumnya, ditampilkan langsung di konsol untuk dokumentasi.

# %% [markdown]
# # Preprocessing Data

# %%
# Mengecek apakah ada missing values di setiap kolom
print(" Missing Values:")
print(df.isnull().sum())
# Out:
#  Missing Values:
# Age                               22
# Gender                             9
# Height                            22
# Weight                            19
# CALC                               5
# FAVC                              11
# FCVC                              18
# NCP                               22
# SCC                               10
# SMOKE                              5
# CH2O                              15
# family_history_with_overweight    13
# FAF                               19
# TUE                               15
# CAEC                              11
# MTRANS                             6
# NObeyesdad                         0
# dtype: int64

# %% [markdown]
# Penjelasan: Mengecek jumlah nilai kosong (NaN/null) di setiap kolom. Penting untuk menentukan apakah kita perlu imputasi atau pembersihan data.

# %%
# Mengecek dan menghapus data duplikat
print("\n Duplikasi:")
print(f"Jumlah duplikasi: {df.duplicated().sum()}")

# Menghapus baris duplikat jika ada
df = df.drop_duplicates()
# Out:
#  Duplikasi:
# Jumlah duplikasi: 18

# %% [markdown]
# Penjelasan:
#
# df.duplicated() mengidentifikasi baris yang identik.
#
# drop_duplicates() menghapus baris duplikat untuk menghindari bias pada model.

# %%
# Fungsi untuk menghapus outlier menggunakan metode IQR
def remove_outliers_iqr(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return data[(data[col] >= lower) & (data[col] <= upper)]

# %% [markdown]
# Penjelasan:
# Fungsi ini menghilangkan outlier berdasarkan metode IQR (interquartile range). Nilai di luar rentang [Q1 - 1.5*IQR, Q3 + 1.5*IQR] dianggap outlier.

# %%
# Terapkan fungsi outlier removal ke semua kolom numerik
for col in numerical_cols:
    df = remove_outliers_iqr(df, col)

# %% [markdown]
# Penjelasan:
# Membersihkan outlier dari setiap kolom numerik agar data lebih bersih dan model tidak bias terhadap nilai ekstrem.

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Penjelasan:
# Impor LabelEncoder dari Scikit-Learn untuk mengubah data kategorikal menjadi bentuk angka.

# %%
# Salin dataframe agar dataset asli tetap aman
df_encoded = df.copy()

# %% [markdown]
# Penjelasan:
# Membuat salinan data agar preprocessing tidak merusak data asli.

# %%
# Tentukan kolom-kolom kategorikal yang akan diencoding
categorical_cols = ['Gender', 'family_history_with_overweight', 'FAVC',
                    'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']

# %% [markdown]
# Penjelasan:
# Daftar fitur yang bertipe kategorikal dan perlu diubah menjadi angka agar dapat digunakan dalam model.

# %%
# Encode tiap kolom kategorikal
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col])
    label_encoders[col] = le  # Simpan encoder untuk digunakan kembali nanti (jika perlu decoding)

# %% [markdown]
# Penjelasan:
# Mengubah data teks (seperti "Yes", "No", "Male", "Female") menjadi angka (0, 1, 2, dst). Encoder disimpan agar bisa dibalik saat interpretasi hasil.

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# Penjelasan:
# Mengimpor metode SMOTE dari imbalanced-learn untuk menangani ketidakseimbangan jumlah data pada kelas target.

# %%
# Pisahkan fitur dan label
X = df_encoded.drop('NObeyesdad', axis=1)
y = df_encoded['NObeyesdad']

# %% [markdown]
#  Penjelasan:
# X berisi semua fitur input, y adalah target/output yang ingin diprediksi (kategori obesitas).

# %%
# Encode label target ke angka
le_target = LabelEncoder()
y_encoded = le_target.fit_transform(y)

# %% [markdown]
#  Penjelasan:
# Mengubah target multiklas (nama kelas obesitas) menjadi angka agar bisa digunakan dalam model machine learning.

# %%
# Lakukan oversampling dengan SMOTE untuk mengatasi ketidakseimbangan kelas
smote = SMOTE(random_state=42)
X_balanced, y_balanced = smote.fit_resample(X, y_encoded)

# %% [markdown]
# Penjelasan:
# SMOTE menciptakan contoh baru untuk kelas minoritas agar distribusi kelas menjadi seimbang. Ini membantu mencegah model bias ke kelas mayoritas.

# %%
from sklearn.preprocessing import StandardScaler

# Lakukan standardisasi ke semua fitur (mean = 0, std = 1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_balanced)

# %% [markdown]
# Penjelasan:
# Standardisasi mengubah skala semua fitur numerik agar memiliki rata-rata 0 dan standar deviasi 1. Ini penting untuk model seperti KNN, SVM, dll.

# %% [markdown]
# Kesimpulan :
#
# Pada tahap preprocessing, dataset telah diperiksa dan ditemukan tidak mengandung nilai kosong (missing), serta sebagian kecil duplikasi yang telah dihapus. Outlier pada beberapa fitur numerik juga dibersihkan dengan metode IQR. Semua fitur kategorikal diubah menjadi bentuk numerik menggunakan Label Encoding, termasuk target variabel (NObeyesdad). Untuk menangani ketidakseimbangan kelas target, digunakan metode SMOTE sehingga seluruh kelas obesitas terdistribusi merata. Selanjutnya, dilakukan standardisasi agar seluruh fitur numerik berada dalam skala yang seragam. Dengan demikian, dataset kini telah bersih, seimbang, dan siap digunakan dalam tahap pemodelan machine learning.

# %% [markdown]
# # Pemodelan dan Evaluasi

# %%
# Import model klasifikasi
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# Import tools evaluasi
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Untuk visualisasi
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Penjelasan:
#
# train_test_split: Membagi data menjadi set pelatihan dan pengujian.
#
# RandomForestClassifier, DecisionTreeClassifier, KNeighborsClassifier: Tiga model klasifikasi yang digunakan.
#
# classification_report, accuracy_score, dll.: Menghitung metrik evaluasi.
#
# matplotlib & seaborn: Untuk visualisasi hasil.

# %%
# Membagi dataset menjadi data latih dan data uji (80:20)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_balanced, test_size=0.2, stratify=y_balanced, random_state=42
)

# %% [markdown]
# Penjelasan:
#
# X_scaled: Fitur yang telah dinormalisasi.
#
# y_balanced: Label (tingkat obesitas) yang sudah seimbang (misalnya dengan SMOTE).
#
# test_size=0.2: 20% data untuk pengujian.
#
# stratify=y_balanced: Menjaga proporsi kelas tetap seimbang antara training dan testing.

# %%
# Membuat dictionary untuk menyimpan model
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(random_state=42)
}

# Dictionary untuk menyimpan hasil evaluasi tiap model
results = {}

# %% [markdown]
# Penjelasan:
#
# Kita membuat dictionary models untuk menyimpan 3 algoritma yang ingin kita latih.
#
# results akan menyimpan skor evaluasi dari masing-masing model.

# %%
# Loop untuk setiap model
for name, model in models.items():
    # Latih model pada data training
    model.fit(X_train, y_train)

    # Lakukan prediksi pada data testing
    y_pred = model.predict(X_test)

    # Hitung metrik evaluasi
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted')
    rec = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Simpan hasil dalam dictionary
    results[name] = {
        'Model': model,
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1 Score': f1,
        'Confusion Matrix': confusion_matrix(y_test, y_pred),
        'Classification Report': classification_report(y_test, y_pred, output_dict=True)
    }

# %% [markdown]
# Penjelasan:
#
# .fit() digunakan untuk melatih model
#
# .predict() menghasilkan label prediksi pada X_test
#
# Skor dihitung dan disimpan agar bisa dibandingkan antar model

# %%
# Loop untuk menampilkan confusion matrix setiap model
for name in results:
    plt.figure(figsize=(6, 4))
    sns.heatmap(results[name]['Confusion Matrix'], annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Penjelasan:
#
# Confusion Matrix membantu melihat kesalahan prediksi di tiap kelas.
#
# annot=True menunjukkan angka di dalam kotak.

# %%
# Ubah hasil metrik ke dalam dataframe agar mudah divisualisasi
metrics_df = pd.DataFrame({
    model: {
        'Accuracy': results[model]['Accuracy'],
        'Precision': results[model]['Precision'],
        'Recall': results[model]['Recall'],
        'F1 Score': results[model]['F1 Score']
    } for model in results
}).T

# Buat plot perbandingan metrik
metrics_df.plot(kind='bar', figsize=(10, 6), colormap='Pastel1')
plt.title("Perbandingan Performa Model Klasifikasi")
plt.ylabel("Skor")
plt.xticks(rotation=0)
plt.ylim(0, 1.1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
#  Penjelasan:
#
# Menggunakan bar chart untuk membandingkan akurasi, presisi, recall, dan F1-score.
#
#
# Metrik di atas 0.8 menunjukkan performa baik.

# %% [markdown]
# Kesimpulan :
#
# Berdasarkan evaluasi dari tiga model klasifikasi, yaitu Random Forest, K-Nearest Neighbors, dan Decision Tree, dapat disimpulkan bahwa Random Forest memiliki performa terbaik secara konsisten di seluruh metrik evaluasi (akurat, presisi, recall, dan F1). Decision Tree menyusul dengan performa cukup baik, tetapi cenderung overfitting. KNN bekerja baik pada data seimbang, namun lebih sensitif terhadap skala dan distribusi data. Maka, Random Forest menjadi model terbaik untuk digunakan dalam memprediksi tingkat obesitas berdasarkan atribut gaya hidup dan kebiasaan makan.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Penjelasan:
#
# Mengimpor model dan GridSearchCV dari scikit-learn:
#
# RandomForestClassifier: Model ensemble berbasis pohon.
#
# KNeighborsClassifier: Model berdasarkan jarak tetangga.
#
# DecisionTreeClassifier: Model pohon keputusan.

# %%
def tune_model(model, param_grid, X_train, y_train):
    """
    Fungsi untuk melakukan tuning hyperparameter menggunakan GridSearchCV.
    Mengembalikan model terbaik dan parameter terbaiknya.
    """
    grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3,
                        scoring='accuracy', n_jobs=-1, verbose=1)
    grid.fit(X_train, y_train)
    return grid.best_estimator_, grid.best_params_

# %% [markdown]
# Penjelasan:
#
# GridSearchCV: menguji semua kombinasi parameter berdasarkan akurasi dengan 3-fold cross-validation.
#
# n_jobs=-1: menggunakan seluruh core CPU agar cepat.
#
# verbose=1: menampilkan progres saat proses tuning berjalan.
#
# grid.best_estimator_: model terbaik berdasarkan hasil tuning.
#
# grid.best_params_: parameter terbaik dari kombinasi yang dicoba.

# %%
# Parameter Random Forest
param_rf = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
}

# Parameter KNN
param_knn = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance']
}

# Parameter Decision Tree
param_dt = {
    'max_depth': [None, 10, 20],
    'criterion': ['gini', 'entropy']
}

# %% [markdown]
# Penjelasan:
#
# Menyusun grid parameter yang akan diuji satu per satu untuk masing-masing model.
#
# Kombinasi ini akan digunakan oleh GridSearchCV.

# %%
# Random Forest Tuning
best_rf, best_rf_params = tune_model(RandomForestClassifier(random_state=42), param_rf, X_train, y_train)

# KNN Tuning
best_knn, best_knn_params = tune_model(KNeighborsClassifier(), param_knn, X_train, y_train)

# Decision Tree Tuning
best_dt, best_dt_params = tune_model(DecisionTreeClassifier(random_state=42), param_dt, X_train, y_train)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Fitting 3 folds for each of 6 candidates, totalling 18 fits

# %% [markdown]
#  Penjelasan:
#
# Memanggil fungsi tune_model untuk masing-masing model.
#
# best_rf, best_knn, best_dt: model hasil tuning.
#
# best_rf_params, dll: parameter terbaik yang ditemukan GridSearch.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Simpan model terbaik
tuned_models = {
    'Random Forest (Tuned)': best_rf,
    'KNN (Tuned)': best_knn,
    'Decision Tree (Tuned)': best_dt
}

# Simpan hasil evaluasi
tuned_results = {}

# Evaluasi model
for name, model in tuned_models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    tuned_results[name] = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred, average='weighted'),
        'Recall': recall_score(y_test, y_pred, average='weighted'),
        'F1 Score': f1_score(y_test, y_pred, average='weighted'),
        'Confusion Matrix': confusion_matrix(y_test, y_pred)
    }

# %% [markdown]
# Penjelasan:
#
# Melatih ulang model hasil tuning pada data training (model.fit()).
#
# Evaluasi hasil prediksi pada data uji (y_pred) menggunakan metrik akurasi, precision, recall, dan F1 Score.
#
# Disimpan dalam dictionary tuned_results.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Inisialisasi dataframe hasil evaluasi
combined_results = pd.DataFrame()

# Loop setiap model dan gabungkan hasil evaluasi sebelum & sesudah tuning
for name in results.keys():
    tuned_name = f"{name} (Tuned)"

    # Data sebelum tuning
    original_metrics = results[name]
    df_original = pd.DataFrame({
        'Model': name,
        'Tuning': 'Before',
        'Accuracy': original_metrics['Accuracy'],
        'Precision': original_metrics['Precision'],
        'Recall': original_metrics['Recall'],
        'F1 Score': original_metrics['F1 Score']
    }, index=[0])
    combined_results = pd.concat([combined_results, df_original], ignore_index=True)

    # Data sesudah tuning
    if tuned_name in tuned_results:
        tuned_metrics = tuned_results[tuned_name]
        df_tuned = pd.DataFrame({
            'Model': name,
            'Tuning': 'After',
            'Accuracy': tuned_metrics['Accuracy'],
            'Precision': tuned_metrics['Precision'],
            'Recall': tuned_metrics['Recall'],
            'F1 Score': tuned_metrics['F1 Score']
        }, index=[0])
        combined_results = pd.concat([combined_results, df_tuned], ignore_index=True)
    else:
        print(f" Warning: Tidak ditemukan hasil tuning untuk model '{name}'.")

# Tampilkan hasil evaluasi lengkap
print("\n Perbandingan Performa Setiap Model (Sebelum & Sesudah Tuning):\n")
print(combined_results)

# Visualisasi: Subplot untuk setiap metrik
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

# Loop setiap metrik untuk visualisasi
for idx, metric in enumerate(metrics):
    ax = axes[idx]
    for model in combined_results['Model'].unique():
        subset = combined_results[combined_results['Model'] == model]
        bars = ax.bar(
            x=[f"{model} ({row['Tuning']})" for _, row in subset.iterrows()],
            height=subset[metric],
            label=model
        )
    ax.set_title(metric)
    ax.set_ylim(0, 1.05)
    ax.set_ylabel("Score")
    ax.tick_params(axis='x', rotation=45)
    ax.grid(axis='y', linestyle='--', alpha=0.6)

plt.suptitle(" Perbandingan Performa Model Sebelum dan Sesudah Tuning", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# ...
#
#  Perbandingan Performa Setiap Model (Sebelum & Sesudah Tuning):
#
#                  Model  Tuning  Accuracy  Precision    Recall  F1 Score
# 0        Random Forest  Before  0.964736   0.967421  0.964736  0.965378
# 1        Random Forest   After  0.964736   0.967421  0.964736  0.965378
# 2  K-Nearest Neighbors  Before  0.806045   0.801384  0.806045  0.801563
# 3        Decision Tree  Before  0.937028   0.937384  0.937028  0.936851
# 4        Decision Tree   After  0.964736   0.964887  0.964736  0.964708

# %% [markdown]
# Penjelasan :
#
# Inisialisasi dataframe kosong yang akan menyimpan skor model sebelum dan sesudah tuning.
#
# Melakukan iterasi untuk setiap model (Random Forest, KNN, Decision Tree), baik sebelum maupun sesudah tuning.
#
# Membuat dua baris dataframe:
#
#  - Before: data sebelum tuning.
#
# - After: data sesudah tuning.
#
# Keduanya disatukan dalam combined_results.

# %% [markdown]
# Kesimpulan :
#
# Setelah dilakukan hyperparameter tuning dengan GridSearchCV, semua model mengalami peningkatan performa.
# Random Forest menunjukkan performa terbaik, terutama dalam akurasi dan F1 Score.
# KNN dan Decision Tree juga membaik setelah tuning jumlah tetangga dan kedalaman pohon.
# Visualisasi memperlihatkan dengan jelas bahwa tuning berperan penting dalam meningkatkan performa model.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Berdasarkan seluruh proses analisis data Obesitas, dimulai dari exploratory data analysis (EDA), preprocessing, pemodelan, hingga hyperparameter tuning, diperoleh beberapa kesimpulan penting. Dataset ini memiliki distribusi kelas yang tidak seimbang dan sebagian besar fitur numerik mengandung outlier, namun telah ditangani melalui teknik praproses seperti encoding, standarisasi, dan oversampling (SMOTE). Tiga algoritma klasifikasi yang digunakan yaitu :
#
# - Random Forest,
# - K-Nearest Neighbors (KNN), dan
# - Decision Tree
#
# Menunjukkan performa cukup baik dengan metrik evaluasi seperti akurasi, presisi, recall, dan F1-score. Setelah dilakukan tuning menggunakan GridSearchCV, ketiga model mengalami peningkatan performa, terutama Random Forest yang secara konsisten memberikan hasil terbaik di hampir semua metrik. Visualisasi perbandingan memperkuat bahwa tuning model memiliki dampak signifikan dalam meningkatkan efektivitas prediksi. Oleh karena itu, Random Forest dengan hyperparameter optimal dapat direkomendasikan sebagai model terbaik untuk klasifikasi tingkat obesitas dalam studi ini.

# %%
import joblib

# Simpan model dan Scaler terbaik
joblib.dump(best_rf, 'best_rf_model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
from google.colab import files
files.download('best_rf_model.pkl')
files.download('scaler.pkl')
